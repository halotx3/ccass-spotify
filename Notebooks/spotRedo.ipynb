# %%
#Created this for getting the year from the spotify api
import pandas as pd
import numpy as np
import config
from sqlalchemy import create_engine
import tekore as tk

# %%
client_id = config.spot_id
client_secret = config.spot_secret

app_token = tk.request_client_token(client_id, client_secret)

# %%
spotify = tk.Spotify(app_token)

album = spotify.album('3RBULTZJ97bvVzZLpxcB0j')
for track in album.tracks.items:
    print(track.track_number, track.name)
# Out:
# 1 The Path
# 2 Atlas Stone
# 3 Cockroach King
# 4 In Memoriam
# 5 Because It's There
# 6 Falling Back To Earth
# 7 As Death Embraces
# 8 Pareidolia
# 9 Somebody
# 10 The Path Unbeaten
# 11 Nobody

# %%
spotify_data = "../Resources/cleaned_spotify.csv"
spotify_df = pd.read_csv(spotify_data)

spotify_df.head()
# Out:
#    Unnamed: 0  genre             artist                             track  \
# 0           0  Movie     Henri Salvador       C'est beau de faire un Show
# 1           1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2           2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
# 3           3  Movie     Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4           4  Movie       Fabien Nataf                         Ouverture
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
# 3  0Gc6TVm52BwZD07Ki6tIvf           0         0.703         0.240
# 4  0IuslXpMROHdEPvSl1fTQK           4         0.950         0.331
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0        99373   0.910             0.000  C#    0.3460    -1.828  Major
# 1       137373   0.737             0.000  F#    0.1510    -5.559  Minor
# 2       170267   0.131             0.000   C    0.1030   -13.879  Minor
# 3       152427   0.326             0.000  C#    0.0985   -12.178  Major
# 4        82625   0.225             0.123   F    0.2020   -21.150  Major
#
#    speechiness    tempo time_signature  valence
# 0       0.0525  166.969            4/4    0.814
# 1       0.0868  174.003            4/4    0.816
# 2       0.0362   99.488            5/4    0.368
# 3       0.0395  171.758            4/4    0.227
# 4       0.0456  140.576            4/4    0.390

# %%
spotify_df.iloc[100:199]
# Out:
#      Unnamed: 0  genre          artist                         track  \
# 100         100  Movie          Chorus           Kaisi Anokhi Mehfil
# 101         101  Movie  Henri Salvador            24 heures par jour
# 102         102  Movie         Choeurs  Georges Bizet : Sur la place
# 103         103  Movie          Chorus                  Daivapithave
# 104         104  Movie          Chorus       Ven a una nave espacial
# ..          ...    ...             ...                           ...
# 194         194    R&B     Iggy Azalea                   Black Widow
# 195         195    R&B  Kelly Clarkson                  Love So Soft
# 196         196    R&B   PARTYNEXTDOOR                      Not Nice
# 197         197    R&B      Tory Lanez            Pa Mi (with Ozuna)
# 198         198    R&B      The Weeknd                A Lonely Night
#
#                    track_id  popularity  acousticness  danceability  \
# 100  3RS1F5oukDho2Wcaulaf8A           0        0.6360         0.615
# 101  3RZCz2Udhx5S9nRMasEZD5           0        0.9510         0.805
# 102  3SGmQRE8io8waO8BqDufdT           0        0.9740         0.390
# 103  3U70EglrYNe7h8QdL8oSBR           0        0.5230         0.627
# 104  3UkjsupdIvhkqnNqAZ3KAQ           1        0.5060         0.653
# ..                      ...         ...           ...           ...
# 194  7pNC5ZIKtwUK0ReSpM3P9f          65        0.1810         0.741
# 195  16QN8cBubEq706vNtPpOME          67        0.0053         0.808
# 196  4STaHtfguDMkWbPEo6Fwcx          69        0.0253         0.598
# 197  0CYLDwvvpJQySLA5CvqvSl          71        0.0983         0.596
# 198  0ifooM33X1iBxVYyOkSbXW          68        0.0431         0.853
#
#      duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 100       234480   0.846          0.000076   D    0.0847    -4.381  Minor
# 101       153973   0.156          0.000000   F    0.1750   -13.312  Major
# 102       375258   0.196          0.000008  A#    0.1460   -18.037  Major
# 103       225307   0.422          0.000000   E    0.1360   -10.800  Major
# 104        66320   0.450          0.000000   G    0.3850    -7.184  Major
# ..           ...     ...               ...  ..       ...       ...    ...
# 194       209423   0.726          0.000189  D#    0.1110    -3.770  Minor
# 195       172427   0.581          0.000012   B    0.0828    -5.430  Major
# 196       202661   0.496          0.001320   C    0.1200    -9.309  Major
# 197       216689   0.557          0.000000  C#    0.0565    -7.522  Minor
# 198       220173   0.663          0.000009   G    0.0891    -6.955  Minor
#
#      speechiness    tempo time_signature  valence
# 100       0.0909  111.790            4/4    0.924
# 101       0.1060  117.846            4/4    0.512
# 102       0.0626   98.843            4/4    0.372
# 103       0.0262   74.050            4/4    0.387
# 104       0.0402  125.081            4/4    0.663
# ..           ...      ...            ...      ...
# 194       0.1430  163.991            4/4    0.527
# 195       0.0700  130.012            4/4    0.758
# 196       0.0804  128.060            4/4    0.725
# 197       0.1340  133.247            5/4    0.661
# 198       0.0755  113.999            4/4    0.864
#
# [99 rows x 19 columns]
